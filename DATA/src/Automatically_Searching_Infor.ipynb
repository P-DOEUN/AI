# %%
import pandas as pd

# %%
data = pd.read_csv('A Track 학습셋.csv')
data
# Out:
#        Log_Number                                            payload  \
# 0               0  GET /forum1_professionnel.asp?n=/.\\\"./.\\\"....
# 1               1  POST /owa/auth/logon.aspx?replaceCurrent=1%22%...
# 2               2  GET /goods/goods_search?display_type=list&arr_...
# 3               3                             GET / HTTP/1.1\r\n\r\n
# 4               4  GET /sub_04_1_read.php?page=1&id=31%29%3BSELEC...
# ...           ...                                                ...
# 44995       44995  GET /app/javascript/js/skin-responsive.js?v=%3...
# 44996       44996  GET /board/?category=type+%25SYSTEMROOT%25%5Cw...
# 44997       44997  POST /sub_02_4.php HTTP/1.1\r\nContent-Length:...
# 44998       44998  GET /admin/myadmin HTTP/1.1\r\nHost: lab.colle...
# 44999       44999  GET /goods/goods_search?display_type=list&arr_...
#
#                label_action
# 0      System_Cmd_Execution
# 1      System_Cmd_Execution
# 2             SQL_Injection
# 3                 HOST_Scan
# 4      System_Cmd_Execution
# ...                     ...
# 44995  System_Cmd_Execution
# 44996  System_Cmd_Execution
# 44997         SQL_Injection
# 44998       Path_Disclosure
# 44999    Vulnerability_Scan
#
# [45000 rows x 3 columns]

# %%
data = data[['payload', 'label_action']]
data
# Out:
#                                                  payload          label_action
# 0      GET /forum1_professionnel.asp?n=/.\\\"./.\\\"....  System_Cmd_Execution
# 1      POST /owa/auth/logon.aspx?replaceCurrent=1%22%...  System_Cmd_Execution
# 2      GET /goods/goods_search?display_type=list&arr_...         SQL_Injection
# 3                                 GET / HTTP/1.1\r\n\r\n             HOST_Scan
# 4      GET /sub_04_1_read.php?page=1&id=31%29%3BSELEC...  System_Cmd_Execution
# ...                                                  ...                   ...
# 44995  GET /app/javascript/js/skin-responsive.js?v=%3...  System_Cmd_Execution
# 44996  GET /board/?category=type+%25SYSTEMROOT%25%5Cw...  System_Cmd_Execution
# 44997  POST /sub_02_4.php HTTP/1.1\r\nContent-Length:...         SQL_Injection
# 44998  GET /admin/myadmin HTTP/1.1\r\nHost: lab.colle...       Path_Disclosure
# 44999  GET /goods/goods_search?display_type=list&arr_...    Vulnerability_Scan
#
# [45000 rows x 2 columns]

# %%
data = data[(data['label_action'] == 'Automatically_Searching_Infor')]
data
# Out:
#                                                  payload  \
# 111    GET /_vti_pvt/services.org HTTP/1.1\r\nConnect...
# 125    HEAD /_app_bin HTTP/1.1\r\nUser-Agent: Mozilla...
# 154    GET /pligg/ HTTP/1.1\r\nHost: 10.0.17.20\r\nCo...
# 230    HEAD /events4.nsf HTTP/1.1\r\nConnection: keep...
# 344    GET /b/ HTTP/1.1\r\nConnection: close\r\nUser-...
# ...                                                  ...
# 44587  GET /access/ HTTP/1.1\r\nUser-Agent: Mozilla/5...
# 44766  GET / HTTP/1.1\r\nConnection: keep-alive\r\nUs...
# 44777  GET / HTTP/1.1\r\nConnection: close\r\nUser-Ag...
# 44792  GET /piranha/ HTTP/1.1\r\nConnection: close\r\...
# 44989  GET /sub/t8.back HTTP/1.1\r\nUser-Agent: Wget/...
#
#                         label_action
# 111    Automatically_Searching_Infor
# 125    Automatically_Searching_Infor
# 154    Automatically_Searching_Infor
# 230    Automatically_Searching_Infor
# 344    Automatically_Searching_Infor
# ...                              ...
# 44587  Automatically_Searching_Infor
# 44766  Automatically_Searching_Infor
# 44777  Automatically_Searching_Infor
# 44792  Automatically_Searching_Infor
# 44989  Automatically_Searching_Infor
#
# [1119 rows x 2 columns]

# %%
data.to_json('Automatically_Searching_Infor.json', 'records')

# %%
import json

# %%
with open('Automatically_Searching_Infor.json', 'r') as f:
    data = json.load(f)

# %%
import urllib.parse  #URL 처리와 관련된 여러 유용한 함수와 클래스 제공

def unquote(text):
    k = 0               #반복 회수를 세기 위한 변수 k
    uq_prev = text      #uq_prev text 인자 받은거 입력
    while(k < 100):     #반복 작업을 100회 이내로 실행
        uq = urllib.parse.unquote_plus(uq_prev)
        if uq == uq_prev:
            break
        else:
            uq_prev = uq
    
    return uq_prev

def remove_new_line(text):
    text = text.strip()
    text = ' '.join(text.splitlines())
    
    return text

def remove_multiple_whitespaces(text):
    return ' '.join(text.split())

def clean_pattern(pattern):
    pattern = unquote(pattern)                      #url decoding
    pattern = remove_new_line(pattern)              #\n 줄바꿈 문자 제거
    pattern = pattern.lower()                       #소문자로 바꾸는거
    pattern = remove_multiple_whitespaces(pattern)  # 공백 제거
    
    return pattern


def prepare_data(x):
    out = {}            #var dict
    out['pattern'] = clean_pattern(x['payload'])
    
    if x['label_action'] == 'Automatically_Searching_Infor':
        out['label_action'] = 'Automatically_Searching_Infor'
    
    return out

# %%
Vulnerability_Scan = list(map(prepare_data, data))
Vulnerability_Scan
# Out:
# [{'pattern': 'get /_vti_pvt/services.org http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /_app_bin http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /pligg/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /events4.nsf http/1.1\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /b/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /data/t1.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /gfx/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /payment/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /fckeditor/editor/filemanager/browser/default/connectors/test.html http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /pages/indexheader.php http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /../../../../../../../../../../etc/passwd http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /telerik.web.ui.dialoghandler.aspx?dp=//// http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /banners/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /delete/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /webadmin.jsp http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /demos/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head //system.html http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /font/t10.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /feed/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /etc/passwd http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /openvbx/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cwhp/auditlog.do?file=..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\boot.ini http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /imagenes/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /admin/t3.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /stsrc.nsf http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /bnnr.php http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /aw/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /assetmanager/assetmanager.asp http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /weblink_cat_list.php http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /transito/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /fckeditor/editor/filemanager/connectors/test.html http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /word/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /readme/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /login.php http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /store/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /phpsecurepages/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /acceso/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /connect/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /web-inf/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /printer/image http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /my/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /statusnet/readme http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /web-console/serverinfo.jsp http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /getsimple/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /browser/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /objects/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head ../../../../../../../..//var/mobile/library/addressbook/addressbook.sqlitedb http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cgis/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /5/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cwhp/auditlog.do?file=..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\boot.ini http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /config/t4.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /upload/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /moderator/admin.aspx http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /health/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /ecoder/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sub/t8.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sdk/../../../../../../../etc/vmware/hostd/vminventory.xml http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /web-inf/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /sitecore/system/settings/security/profiles http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /mail5.box http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /.htaccess http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cwhp/auditlog.do?file=..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\boot.ini http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /employees/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /data/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /ehcp/?op=applyfordomainaccount http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /admin/t3.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /adminlogin.aspx http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /reg_1.htm http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /mxportal/home/en_us/servicetools.gif http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /telerik.web.ui.dialoghandler.aspx?dp=//// http/1.1\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /login.php http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /typo3/readme.txt http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /supply/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /messaging/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /config/t4.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /photogallery_open.php http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /admin2.php http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /telerik.web.ui.dialoghandler.aspx?dp=//// http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /author/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /tmp/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sitecore/shell/sitecore.version.xml http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /webreps/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /citrix//accessplatform/auth/clientscripts/cookies.js http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /nmaplowercheck1671435788 http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /../../../../../../../../../../etc/passwd http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /notes/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /css/t7.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /store/docs/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /mediawiki/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /phpmyadmin-2.6.0-rc3/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /crons/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /phpinfo.php http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /clients/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /feed/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /l/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /topaccess/images/riogrande/rio_ppc.gif http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /../../../../../../../../../../etc/passwd http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /compressed/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /docs/changelog.html http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sdk/../../../../../../../etc/vmware/hostd/vminventory.xml http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /o/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /controller/t6.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /general/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sslkeys/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cwhp/auditlog.do?file=..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\boot.ini http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cwhp/auditlog.do?file=..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\boot.ini http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /netscape/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /default/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /j2eeexamplesjsp/ http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /polls/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /backup.sql http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cbi-bin/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /font/t10.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /nchelp/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /userdb/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /webdb/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /printers/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /openvbx/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /data/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /nmaplowercheck1671438162 http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /oprocmgr-service/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /data/t1.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /backup.sql http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /news/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /script/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cluster/cluster http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /html/news_fckeditor/editor/filemanager/upload/php/upload.php http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /phpmyadmin-2.6.1-pl1/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /manual/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /u/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /controller/t6.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /email/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /../../../../../../../../../../etc/passwd http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sub/t8.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /demoauct/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /licenses/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /squid/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /typo3/readme.txt http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /banner/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /job/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /data/t1.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /_vti_pvt/service.pwd http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head //system.html http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sdk/../../../../../../../etc/vmware/hostd/vminventory.xml http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head ../../../../../../../..//var/mobile/library/addressbook/addressbook.sqlitedb http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /c/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /tests/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /.nsf/../winnt/win.ini http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /advwebadmin/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /cmspages.php http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /ddreport/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /b.sql http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /conecta/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /font/t10.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /web-inf/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head ../../../../../../../..//var/mobile/library/addressbook/addressbook.sqlitedb http/1.1\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /webstats/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /feed/atom http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /search/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /oprocmgr-service/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /fpdb/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /admins/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /web-console/serverinfo.jsp http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /changelog.txt http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /data/t1.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /bin/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /font/t10.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /web-inf/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /www3/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /_vti_pvt/services.org http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /install.mysql.txt http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /i/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /mem/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sdk/../../../../../../../etc/vmware/hostd/vminventory.xml http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
# ...
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /compressed/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /panel-administracion/admin.aspx http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /hosted/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /fckeditor/editor/filemanager/connectors/php/config.php http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sdk/../../../../../../../etc/vmware/hostd/vminventory.xml http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /mono/1.1/index.aspx http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /hlstats/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /phpinfo.php http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /shell-cgi/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /dcforum/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cfdocs/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /xml/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /webaccess/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /w2k/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /mpcgi/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /controller/t6.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /upload/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /t2.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /default/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sdk/../../../../../../../etc/vmware/hostd/vminventory.xml http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /events4.nsf http/1.1\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /telerik.web.ui.dialoghandler.aspx?dp=//// http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sql/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /iisadmin/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /register/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /search/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cbi-bin/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /css/t7.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /js/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /etc/passwd http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /cfide/componentutils/login.cfm http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /tarjetas/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /../../../../../../../../../../etc/passwd http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /nmaplowercheck1671437379 http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /pages/t5.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /sslkeys/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /config/ http/1.1\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /telerik.web.ui.dialoghandler.aspx?dp=//// http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /citrix//accessplatform/auth/clientscripts/cookies.js http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /css/t7.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /telerik.web.ui.dialoghandler.aspx?dp=//// http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /fckeditor/editor/filemanager/connectors/test.html http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /cwhp/auditlog.do?file=..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\..\\\\boot.ini http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /passwords/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /webmaster/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /stats_old/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /wiki/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /css/t7.back http/1.1\\r\\nuser-agent: wget/1.21\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nhost: 10.0.17.20\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /down/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /services/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /index.php?cat_id=1 http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /buy/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /iisadmin/ http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.20\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'head /citrix//accessplatform/auth/clientscripts/cookies.js http/1.1\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /index.php?cat_id=1 http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nconnection: close\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /empoyees/ http/1.1\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.20\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  {'pattern': 'get /search/ http/1.1\\r\\nhost: 10.0.17.20\\r\\nconnection: close\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\n\\r\\n',
#   'label_action': 'Automatically_Searching_Infor'},
#  ...]

# %%
with open('Automatically_Searching_Infor.json', 'w') as f:
    json.dump(Vulnerability_Scan, f)
