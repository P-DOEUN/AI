# %%
import pandas as pd

# %%
data = pd.read_csv('A Track 학습셋.csv')
data
# Out:
#        Log_Number                                            payload  \
# 0               0  GET /forum1_professionnel.asp?n=/.\\\"./.\\\"....
# 1               1  POST /owa/auth/logon.aspx?replaceCurrent=1%22%...
# 2               2  GET /goods/goods_search?display_type=list&arr_...
# 3               3                             GET / HTTP/1.1\r\n\r\n
# 4               4  GET /sub_04_1_read.php?page=1&id=31%29%3BSELEC...
# ...           ...                                                ...
# 44995       44995  GET /app/javascript/js/skin-responsive.js?v=%3...
# 44996       44996  GET /board/?category=type+%25SYSTEMROOT%25%5Cw...
# 44997       44997  POST /sub_02_4.php HTTP/1.1\r\nContent-Length:...
# 44998       44998  GET /admin/myadmin HTTP/1.1\r\nHost: lab.colle...
# 44999       44999  GET /goods/goods_search?display_type=list&arr_...
#
#                label_action
# 0      System_Cmd_Execution
# 1      System_Cmd_Execution
# 2             SQL_Injection
# 3                 HOST_Scan
# 4      System_Cmd_Execution
# ...                     ...
# 44995  System_Cmd_Execution
# 44996  System_Cmd_Execution
# 44997         SQL_Injection
# 44998       Path_Disclosure
# 44999    Vulnerability_Scan
#
# [45000 rows x 3 columns]

# %%
data = data[['payload', 'label_action']]
data
# Out:
#                                                  payload          label_action
# 0      GET /forum1_professionnel.asp?n=/.\\\"./.\\\"....  System_Cmd_Execution
# 1      POST /owa/auth/logon.aspx?replaceCurrent=1%22%...  System_Cmd_Execution
# 2      GET /goods/goods_search?display_type=list&arr_...         SQL_Injection
# 3                                 GET / HTTP/1.1\r\n\r\n             HOST_Scan
# 4      GET /sub_04_1_read.php?page=1&id=31%29%3BSELEC...  System_Cmd_Execution
# ...                                                  ...                   ...
# 44995  GET /app/javascript/js/skin-responsive.js?v=%3...  System_Cmd_Execution
# 44996  GET /board/?category=type+%25SYSTEMROOT%25%5Cw...  System_Cmd_Execution
# 44997  POST /sub_02_4.php HTTP/1.1\r\nContent-Length:...         SQL_Injection
# 44998  GET /admin/myadmin HTTP/1.1\r\nHost: lab.colle...       Path_Disclosure
# 44999  GET /goods/goods_search?display_type=list&arr_...    Vulnerability_Scan
#
# [45000 rows x 2 columns]

# %%
data = data[(data['label_action'] == 'Leakage_Through_NW')]
data
# Out:
#                                                  payload        label_action
# 23     GET /upload/conf/garden_logo_R0c_icon.ico HTTP...  Leakage_Through_NW
# 27     GET /company/about HTTP/1.1\r\nAccept: */*\r\n...  Leakage_Through_NW
# 186    GET /company/about HTTP/1.1\r\nCache-Control: ...  Leakage_Through_NW
# 210    GET /company/about HTTP/1.1\r\nCache-Control: ...  Leakage_Through_NW
# 224    GET /company/work HTTP/1.1\r\nConnection: Keep...  Leakage_Through_NW
# ...                                                  ...                 ...
# 44711  GET /company/about HTTP/1.1\r\nHost: 10.0.17.1...  Leakage_Through_NW
# 44806  GET /company/work HTTP/1.1\r\nConnection: Keep...  Leakage_Through_NW
# 44921  GET /company/about HTTP/1.1\r\nCache-Control: ...  Leakage_Through_NW
# 44944  GET /company/history HTTP/1.1\r\nUser-Agent: M...  Leakage_Through_NW
# 44980  GET /service/usepolicy HTTP/1.1\r\nHost: 10.0....  Leakage_Through_NW
#
# [956 rows x 2 columns]

# %%
data.to_json('Leakage_Through_NW.json', 'records')

# %%
import json

# %%
with open('Leakage_Through_NW.json', 'r') as f:
    data = json.load(f)

# %%
import urllib.parse  #URL 처리와 관련된 여러 유용한 함수와 클래스 제공

def unquote(text):
    k = 0               #반복 회수를 세기 위한 변수 k
    uq_prev = text      #uq_prev text 인자 받은거 입력
    while(k < 100):     #반복 작업을 100회 이내로 실행
        uq = urllib.parse.unquote_plus(uq_prev)
        if uq == uq_prev:
            break
        else:
            uq_prev = uq
    
    return uq_prev

def remove_new_line(text):
    text = text.strip()
    text = ' '.join(text.splitlines())
    
    return text

def remove_multiple_whitespaces(text):
    return ' '.join(text.split())

def clean_pattern(pattern):
    pattern = unquote(pattern)                      #url decoding
    pattern = remove_new_line(pattern)              #\n 줄바꿈 문자 제거
    pattern = pattern.lower()                       #소문자로 바꾸는거
    pattern = remove_multiple_whitespaces(pattern)  # 공백 제거
    
    return pattern


def prepare_data(x):
    out = {}            #var dict
    out['pattern'] = clean_pattern(x['payload'])
    
    if x['label_action'] == 'Leakage_Through_NW':
        out['label_action'] = 'Leakage_Through_NW'
    
    return out

# %%
Leakage_Through_NW = list(map(prepare_data, data))
Leakage_Through_NW
# Out:
# [{'pattern': 'get /upload/conf/garden_logo_r0c_icon.ico http/1.1\\r\\nhost: www.college.school\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://www.college.school/\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=ko5om3f4ph6i987f2krd79dabgfc7spc\\r\\nif-modified-since: tue, 20 dec 2022 01:41:55 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=75hufa6s4f5dq3p1c110rbavsmcv0bat\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=university http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/company/about\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /member/find_id http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/member/find_pw\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=news http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=news http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=notice\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /favicon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/company\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\nif-modified-since: mon, 19 dec 2022 07:26:44 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_view?code=news&no=22 http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=news\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/outline/bbs_top.html\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=tgagdo380ivs2so2tgh1eseridos021n\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /upload/conf/garden_logo_r0c_icon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\nif-modified-since: mon, 19 dec 2022 04:12:08 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /upload/conf/garden_logo_r0c_icon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/board/board_view?code=news&no=24\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=if036euqp9gaomom50iijf78l8lo8hlm\\r\\nif-modified-since: tue, 20 dec 2022 01:41:37 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=news\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /favicon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/company\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\nif-modified-since: mon, 19 dec 2022 07:26:46 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get / http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /favicon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/var/www/html/data/skin/default_dart/company/index.html\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\nif-modified-since: mon, 19 dec 2022 07:27:44 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=university http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/company/work\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=hvu24e3kjvj2binopvgjeajcjmh6epgc\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=75hufa6s4f5dq3p1c110rbavsmcv0bat\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /upload/conf/garden_logo_r0c_icon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/board/board_list?code=news\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\nif-modified-since: mon, 19 dec 2022 08:05:18 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=result http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=graduate\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /member/join_agreement http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=result\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=hvu24e3kjvj2binopvgjeajcjmh6epgc\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_write?code=inquiry\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=news http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_write?code=inquiry\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=75hufa6s4f5dq3p1c110rbavsmcv0bat\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /nmap/folder/check1671431410 http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.19\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=auh9rm75grdmetapirienjjdflhujpqk\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get / http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/index.html\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=vflghlkhkvrg7mg1pijdsngtguh3p66v\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/company/location\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=hvu24e3kjvj2binopvgjeajcjmh6epgc\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=hvu24e3kjvj2binopvgjeajcjmh6epgc\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=auh9rm75grdmetapirienjjdflhujpqk\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_write?code=inquiry http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/company/history\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=tgagdo380ivs2so2tgh1eseridos021n\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/service/agreement\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=hvu24e3kjvj2binopvgjeajcjmh6epgc\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_view?code=university&no=10\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /upload/conf/garden_logo_r0c_icon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/member/login\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=if036euqp9gaomom50iijf78l8lo8hlm\\r\\nif-modified-since: tue, 20 dec 2022 02:30:19 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': "get /board/board_list?code=notice&search_type=title&search=123= http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=notice&search_type=title&search=123'\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n",
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
# ...
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=welfare http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=university\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_list?code=result http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=welfare\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /nmaplowercheck1671431410 http/1.1\\r\\nuser-agent: mozilla/5.0 (compatible; nmap scripting engine; https://nmap.org/book/nse.html)\\r\\nhost: 10.0.17.19\\r\\nconnection: close\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /favicon.ico http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: image/avif,image/webp,image/apng,image/svg xml,image/*,*/*;q=0.8\\r\\nreferer: http://10.0.17.19/system\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\nif-modified-since: mon, 19 dec 2022 07:12:28 gmt\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\naccept: */*\\r\\nuser-agent: certutil url agent\\r\\nhost: 10.0.17.19\\r\\ncache-control: no-cache\\r\\ncookie: designart_site=auh9rm75grdmetapirienjjdflhujpqk\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work.html http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=bp2ct0bhr2hmdidccem00fjfip3a1uo2\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /js/jquery.mcustomscrollbar.concat.min.js http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nif-modified-since: mon, 19 dec 2022 07:28:59 gmt\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: */*\\r\\nreferer: http://10.0.17.19/\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/agreement http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/index.html http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/location http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /board/board_view?code=university&no=10 http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=university\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=3me5aifltmcpi87n5j6rb21glkp0ugb8\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\nhost: 10.0.17.19\\r\\nconnection: keep-alive\\r\\nupgrade-insecure-requests: 1\\r\\nuser-agent: mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/10.0.2.42 safari/537.36\\r\\naccept: text/html,application/xhtml xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9\\r\\nreferer: http://10.0.17.19/board/board_list?code=university\\r\\naccept-encoding: gzip, deflate\\r\\naccept-language: ko-kr,ko;q=0.9,en-us;q=0.8,en;q=0.7\\r\\ncookie: designart_site=if036euqp9gaomom50iijf78l8lo8hlm\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/work http/1.1\\r\\nconnection: keep-alive\\r\\naccept: */*\\r\\naccept-encoding: identity\\r\\nrange: bytes=0-2147483646\\r\\nuser-agent: microsoft bits/7.8\\r\\nhost: 10.0.17.19\\r\\ncookie: designart_site=o4ds4iiu4r3csjo048nbbsairfvh67ok\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/about http/1.1\\r\\ncache-control: no-cache\\r\\nconnection: keep-alive\\r\\npragma: no-cache\\r\\naccept: */*\\r\\nuser-agent: microsoft-cryptoapi/10.0\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /company/history http/1.1\\r\\nuser-agent: mozilla/5.0 (windows nt; windows nt 10.0; ko-kr) windowspowershell/5.1.19041.2364\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'},
#  {'pattern': 'get /service/usepolicy http/1.1\\r\\nhost: 10.0.17.19\\r\\n\\r\\n',
#   'label_action': 'Leakage_Through_NW'}]

# %%
with open('Leakage_Through_NW.json', 'w') as f:
    json.dump(Leakage_Through_NW, f)
